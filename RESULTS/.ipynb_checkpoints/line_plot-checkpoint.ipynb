# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('SOD.csv')
print(df.shape)
df.head()
# Out:
# (8, 26)
#    ROC   ADULT  ARRHYTHMIA   BANK   COMMUNITIES  COMPAS  CREDITCARD    DRUG  \
# 0  NaN  0.5497      0.7195  0.6115       0.6564  0.7303      0.4114  0.6690
# 1  NaN  0.5187      0.7133  0.6166       0.6743  0.7247      0.4151  0.7101
# 2  NaN  0.4908      0.7107  0.6255       0.6889  0.7267      0.4225  0.6848
# 3  NaN  0.4799      0.7206  0.6311       0.6910  0.7375      0.4284  0.7178
# 4  NaN  0.4913      0.7389  0.6383       0.6854  0.7382      0.4350  0.6783
#
#    GERMAN  INTERNETADS  ...  BANK .1  COMMUNITIES.1     COMPAS.1  \
# 0  0.5681       0.5689  ...      NaN       645.2657  62809130.10
# 1  0.5783       0.5538  ...      NaN       645.2683  62809129.20
# 2  0.5573       0.5703  ...      NaN       645.2706  62809127.86
# 3  0.5762       0.5481  ...      NaN       645.2651  62809126.72
# 4  0.5564       0.5371  ...      NaN       645.2736  62809125.97
#
#    CREDITCARD.1    DRUG.1   GERMAN.1  INTERNETADS.1  PENDIGITS.1  ST-MAT.1  \
# ...

# %%
#CONVERT

df1=df[['ADULT', 'ARRHYTHMIA', 'COMMUNITIES', 'COMPAS', 'DRUG', 'GERMAN', 'INTERNETADS', 'PENDIGITS', 'ST-MAT', 'WIKI4HE']].copy()
df2=df[['ADULT.1', 'ARRHYTHMIA.1', 'COMMUNITIES.1', 'COMPAS.1', 'DRUG.1', 'GERMAN.1', 'INTERNETADS', 'PENDIGITS', 'ST-MAT.1', 'WIKI4HE.1']].copy()

n_df2=(df2-df2.min())/(df2.max()-df2.min())
n_df2

df1_s = np.zeros([10,8])
df2_s = np.zeros([10,8])

df1_a = df1.to_numpy()
df2_a = n_df2.to_numpy()
for i in range(0,10):
    idx = np.argsort(df1_a[:,i])
    for j in range(0,8):
        df1_s[i][j] = df1_a[idx[j]][i]
        df2_s[i][j] = df2_a[idx[j]][i]
        
n_d=n_df2.to_numpy()

# %%
fig = plt.figure(figsize = (12, 8))

plt.xlabel("ROC AUC", fontsize='22')
plt.ylabel("iFscore", fontsize='22')

plt.xticks(fontsize='16')
plt.yticks(fontsize='16')

plt.plot(df1_s[0], df2_s[0], color = 'deeppink', linestyle = 'solid', marker = 'o', markerfacecolor = 'white', markersize = 5, label='Adult')
plt.plot(df1_s[1], df2_s[1], color = 'g', linestyle = 'solid', marker = 'o', markerfacecolor = 'white', markersize = 5, label='Arrhythmia')
plt.plot(df1_s[2], df2_s[2], color = 'r', linestyle = 'solid', marker = 'p', markerfacecolor = 'white', markersize = 5, label='Communities')
plt.plot(df1_s[3], df2_s[3], color = 'b', linestyle = 'solid', marker = 's', markerfacecolor = 'white', markersize = 5, label='Compas')
plt.plot(df1_s[4], df2_s[4], color = 'm', linestyle = 'solid', marker = 'd', markerfacecolor = 'white', markersize = 5, label='Drug')
plt.plot(df1_s[5], df2_s[5], color = 'c', linestyle = 'solid', marker = 'o', markerfacecolor = 'white', markersize = 5, label='German')
plt.plot(df1_s[6], df2_s[6], color = 'tab:brown', linestyle = 'solid', marker = 'p', markerfacecolor = 'white', markersize = 5, label='InternetAds')
plt.plot(df1_s[7], df2_s[7], color = 'lime', linestyle = 'solid', marker = 's', markerfacecolor = 'white', markersize = 5, label='PenDigits')
plt.plot(df1_s[8], df2_s[8], color = 'tab:orange', linestyle = 'solid', marker = 'p', markerfacecolor = 'white', markersize = 5, label='St-Mat')
plt.plot(df1_s[9], df2_s[9], color = 'k', linestyle = 'solid', marker = 's', markerfacecolor = 'white', markersize = 5, label='Wiki4HE')

plt.legend( loc="upper right", bbox_to_anchor=(0.8, 1.1), ncol=5)
plt.show()

# %%
fig = plt.figure(figsize = (12, 8))
z=np.array([5, 10, 20, 30, 45, 60, 80, 100])

plt.xlabel("Parameter", fontsize='22')
plt.ylabel("iFscore", fontsize='22')

plt.xticks(fontsize='16')
plt.yticks(fontsize='16')

plt.plot(z, n_d[:,0], color = 'deeppink', linestyle = 'solid', marker = 'o', markerfacecolor = 'white', markersize = 5, label='Adult')
plt.plot(z, n_d[:,1], color = 'g', linestyle = 'solid', marker = 'o', markerfacecolor = 'white', markersize = 5, label='Arrhythmia')
plt.plot(z, n_d[:,2], color = 'r', linestyle = 'solid', marker = 'p', markerfacecolor = 'white', markersize = 5, label='Communities')
plt.plot(z, n_d[:,3], color = 'b', linestyle = 'solid', marker = 's', markerfacecolor = 'white', markersize = 5, label='Compas')
plt.plot(z, n_d[:,4], color = 'm', linestyle = 'solid', marker = 'd', markerfacecolor = 'white', markersize = 5, label='Drug')
plt.plot(z, n_d[:,5], color = 'c', linestyle = 'solid', marker = 'o', markerfacecolor = 'white', markersize = 5, label='German')
plt.plot(z, n_d[:,6], color = 'tab:brown', linestyle = 'solid', marker = 'p', markerfacecolor = 'white', markersize = 5, label='InternetAds')
plt.plot(z, n_d[:,7], color = 'lime', linestyle = 'solid', marker = 's', markerfacecolor = 'white', markersize = 5, label='PenDigits')
plt.plot(z, n_d[:,8], color = 'tab:orange', linestyle = 'solid', marker = 'p', markerfacecolor = 'white', markersize = 5, label='St-Mat')
plt.plot(z, n_d[:,9], color = 'k', linestyle = 'solid', marker = 's', markerfacecolor = 'white', markersize = 5, label='Wiki4HE')

plt.legend( loc="upper right", bbox_to_anchor=(0.8, 1.1), ncol=5)
plt.show()

# %%
fig = plt.figure(figsize = (12, 8))
z=[5, 10, 20, 30, 45, 60, 80, 100]

plt.xlabel("Parameter", fontsize='22')
plt.ylabel("ROC AUC", fontsize='22')

plt.xticks(fontsize='16')
plt.yticks(fontsize='16')

plt.plot(z, df1_a[:,0], color = 'deeppink', linestyle = 'solid', marker = 'o', markerfacecolor = 'white', markersize = 5, label='Adult')
plt.plot(z, df1_a[:,1], color = 'g', linestyle = 'solid', marker = 'o', markerfacecolor = 'white', markersize = 5, label='Arrhythmia')
plt.plot(z, df1_a[:,2], color = 'r', linestyle = 'solid', marker = 'p', markerfacecolor = 'white', markersize = 5, label='Communities')
plt.plot(z, df1_a[:,3], color = 'b', linestyle = 'solid', marker = 's', markerfacecolor = 'white', markersize = 5, label='Compas')
plt.plot(z, df1_a[:,4], color = 'm', linestyle = 'solid', marker = 'd', markerfacecolor = 'white', markersize = 5, label='Drug')
plt.plot(z, df1_a[:,5], color = 'c', linestyle = 'solid', marker = 'o', markerfacecolor = 'white', markersize = 5, label='German')
plt.plot(z, df1_a[:,6], color = 'tab:brown', linestyle = 'solid', marker = 'p', markerfacecolor = 'white', markersize = 5, label='InternetAds')
plt.plot(z, df1_a[:,7], color = 'lime', linestyle = 'solid', marker = 's', markerfacecolor = 'white', markersize = 5, label='PenDigits')
plt.plot(z, df1_a[:,8], color = 'tab:orange', linestyle = 'solid', marker = 'p', markerfacecolor = 'white', markersize = 5, label='St-Mat')
plt.plot(z, df1_a[:,9], color = 'k', linestyle = 'solid', marker = 's', markerfacecolor = 'white', markersize = 5, label='Wiki4HE')

plt.legend( loc="upper right", bbox_to_anchor=(0.8, 1.1), ncol=5)
plt.show()
